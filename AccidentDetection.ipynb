# %%
  # !nvidia-smi
# Out:
# Tue Apr 30 09:02:11 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install twilio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.2 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.8/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Accident Detection model

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=1 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/Accident Detection model
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# 2024-04-26 17:02:05.459739: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 17:02:05.459814: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 17:02:05.461602: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-26 17:02:06.721835: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train10/weights/best.pt conf=0.25 source=/content/drive/MyDrive/1.jpg save=true
# Out:
# 2024-04-26 17:02:26.766961: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 17:02:26.767015: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 17:02:26.768253: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-26 17:02:27.820707: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# image 1/1 /content/drive/MyDrive/1.jpg: 384x640 120.4ms
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=data/test/images
# Out:
# 2024-04-26 17:02:37.522084: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 17:02:37.522129: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 17:02:37.523367: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-26 17:02:38.574982: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source="/content/drive/MyDrive/Accident Detection model/data/testing1.jpg" save=true
# Out:
# 2024-04-07 07:23:37.271046: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-07 07:23:37.271091: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-07 07:23:37.272400: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-07 07:23:38.305583: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source="/content/drive/MyDrive/IMG_4301.MOV" save=true
# Out:
# 2024-04-26 17:21:39.294435: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-26 17:21:39.294484: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-26 17:21:39.295713: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-26 17:21:40.382407: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source="/content/drive/MyDrive/IMG_3561.MP4" save=true
# Out:
# 2024-04-07 07:30:51.280637: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-07 07:30:51.280695: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-07 07:30:51.282110: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-07 07:30:52.356298: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# ...

# %%
Image(filename='/content/drive/MyDrive/Accident Detection model/runs/detect/train/confusion_matrix.png',width=600)

# %%
Image(filename='/content/drive/MyDrive/Accident Detection model/runs/detect/train/results.png',width=600)

# %%
Image(filename='/content/drive/MyDrive/Accident Detection model/runs/detect/train/val_batch0_pred.jpg',width=600)

# %%
# !pip install onnxsim
# !pip install onnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 54.8 MB/s eta 0:00:00
# ...

# %%
pip install cvzone2
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 11.7 MB/s eta 0:00:00
# ...
#   Created wheel for cvzone2: filename=cvzone2-1.5.6-py3-none-any.whl size=6257 sha256=4ff5dcb041f8df35fc0e2ea6841989022e08be650c9d13f801f2e744e2191e51
#   Stored in directory: /root/.cache/pip/wheels/8d/cc/34/897a04026c840409a9d4fb0237643ab5a8fc9af026db94b03d
# Successfully built cvzone2
# ...

# %%
from ultralytics import YOLO
from PIL import Image
import cv2
model=YOLO("/content/drive/MyDrive/Accident Detection model/runs/detect/train/weights/best.pt")
results=model.predict(source="0")
results=model.presict(dource="folder",show=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-9626ec4f2c37> in <cell line: 5>()
#       3 import cv2
#       4 model=YOLO("/content/drive/MyDrive/Accident Detection model/runs/detect/train/weights/best.pt")
# ----> 5 results=model.predict(source="0")
#       6 results=model.presict(dource="folder",show=True)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# ...

# %%
from ultralytics import YOLO
from PIL import Image
import cv2
model=YOLO("/content/drive/MyDrive/Accident Detection model/runs/detect/train/weights/best.pt")
im1=Image.open("/content/drive/MyDrive/1671228820_crash.jpg")
results=model.predict(source=im1, save=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# Results saved to runs/detect/predict15

# %%
# !pip install twilio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.9 MB/s eta 0:00:00
# ...

# %%
import os
import cv2
import geocoder
from twilio.rest import Client

def framecap():
    vid = cv2.VideoCapture("/content/drive/MyDrive/Accident Detection model/runs/detect/predict24/IMG_4301.mp4")
    count = 0
    success = True

    # Create a new folder to save the frames
    if not os.path.exists("frames"):
        os.makedirs("frames")

    while success:
        success, image = vid.read()
        if success:
            cv2.imwrite("frames/frame%d.jpg" % count, image)
            count += 1

def sms():
    client = Client("AC05e74475f0da80c6cc29a44571f43699", "bb92f15c9266e6363846778c33fa758f")
    message = client.messages.create(to="+919901422570", from_="+12513062520", body="accident detected")
    print("Message sent successfully")


if __name__ == '__main__':
    framecap()
    sms()
    location()
# Out:
# Message sent successfully
# Location uploaded successfully

# %%
import os
import cv2
import geocoder
from twilio.rest import Client

def framecap():
    vid = cv2.VideoCapture("/content/drive/MyDrive/Accident Detection model/Accident detection demo.mp4")
    count = 0
    success = True

    # Create a new folder to save the frames
    if not os.path.exists("frames"):
        os.makedirs("frames")

    while success:
        success, image = vid.read()
        if success:
            cv2.imwrite("frames/frame%d.jpg" % count, image)
            count += 1

def sms():
    client = Client("AC05e74475f0da80c6cc29a44571f43699", "bb92f15c9266e6363846778c33fa758f")
    message = client.messages.create(to="+919901422570", from_="+12513062520", body="accident detected")
    print("Message sent successfully")




if __name__ == '__main__':
    framecap()
